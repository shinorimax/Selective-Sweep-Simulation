# %%
import os
import numpy as np
import tskit
import csv

# ─────────────────────────────────────────────────────────────────────────────
# Helper: jitter node times within each generation (skip samples)
# ─────────────────────────────────────────────────────────────────────────────
def jitter_within_generations(ts: tskit.TreeSequence, eps: float = 1e-9) -> tskit.TreeSequence:
    """
    Make node times strictly increasing within each generation by adding tiny,
    deterministic jitters to nodes that share the same time. Samples (time=0)
    are not jittered. Ordering is by node ID to be deterministic.
    """
    tables = ts.dump_tables()  # safe, editable copy
    times = tables.nodes.time.astype(float).copy()

    # Identify samples so we don't move them off time 0
    is_sample = np.zeros(len(times), dtype=bool)
    is_sample[ts.samples()] = True

    # For each unique time, spread tied non-sample nodes by eps * rank
    for t in np.unique(times):
        idx = np.where(times == t)[0]
        idx = [i for i in idx if not is_sample[i]]
        if len(idx) > 1:
            for rank, node_id in enumerate(sorted(idx)):
                times[node_id] = t + eps * rank

    # Write back and re-sort to keep table invariants
    tables.nodes.set_columns(
        flags=tables.nodes.flags,
        time=times,
        population=tables.nodes.population,
        individual=tables.nodes.individual,
        metadata=tables.nodes.metadata,
        metadata_offset=tables.nodes.metadata_offset,
    )
    tables.sort()
    return tables.tree_sequence()

# ─────────────────────────────────────────────────────────────────────────────
# Main conversion script: export .tree (Newick) + .csv (breakpoints)
# ─────────────────────────────────────────────────────────────────────────────
input_dir = "trees"
output_dir = "trees_newick"
os.makedirs(output_dir, exist_ok=True)

for filename in sorted(os.listdir(input_dir)):
    if filename.endswith(".trees") and filename.startswith("r"):
        input_path = os.path.join(input_dir, filename)
        stem = os.path.splitext(filename)[0]  # e.g. "r3000001"

        # Output files (.tree + .csv)
        output_tree_path = os.path.join(output_dir, f"{stem}.tree")
        output_csv_path  = os.path.join(output_dir, f"{stem}_breaks.csv")

        # Load, jitter, and convert to Newick
        ts = tskit.load(input_path)
        ts = jitter_within_generations(ts, eps=1e-9)

        # Export Newick file (one tree per line)
        with open(output_tree_path, "w") as f:
            for tree in ts.trees():
                f.write(tree.newick() + "\n")

        # Export CSV file with genomic intervals
        with open(output_csv_path, "w", newline="") as cf:
            writer = csv.writer(cf)
            writer.writerow(["file", "tree_index", "left", "right", "mid"])
            for i, tree in enumerate(ts.trees()):
                left, right = tree.interval.left, tree.interval.right
                mid = 0.5 * (left + right)
                writer.writerow([stem, i, left, right, mid])

        print(f"✅ {filename} → {output_tree_path}, {output_csv_path}")

print("🎉 All tree files converted successfully with jitter + interval CSVs!")
# Out:
# ✅ r3000000.trees → trees_newick/r3000000.tree, trees_newick/r3000000_breaks.csv
# ✅ r3000001.trees → trees_newick/r3000001.tree, trees_newick/r3000001_breaks.csv
# ✅ r3000002.trees → trees_newick/r3000002.tree, trees_newick/r3000002_breaks.csv
# ✅ r3000003.trees → trees_newick/r3000003.tree, trees_newick/r3000003_breaks.csv
# ✅ r3000004.trees → trees_newick/r3000004.tree, trees_newick/r3000004_breaks.csv
# ✅ r3000005.trees → trees_newick/r3000005.tree, trees_newick/r3000005_breaks.csv
# ✅ r3000006.trees → trees_newick/r3000006.tree, trees_newick/r3000006_breaks.csv
# ✅ r3000007.trees → trees_newick/r3000007.tree, trees_newick/r3000007_breaks.csv
# ✅ r3000008.trees → trees_newick/r3000008.tree, trees_newick/r3000008_breaks.csv
# ✅ r3000009.trees → trees_newick/r3000009.tree, trees_newick/r3000009_breaks.csv
# ✅ r3000010.trees → trees_newick/r3000010.tree, trees_newick/r3000010_breaks.csv
# ✅ r3000011.trees → trees_newick/r3000011.tree, trees_newick/r3000011_breaks.csv
# ✅ r3000012.trees → trees_newick/r3000012.tree, trees_newick/r3000012_breaks.csv
# ✅ r3000013.trees → trees_newick/r3000013.tree, trees_newick/r3000013_breaks.csv
# ✅ r3000014.trees → trees_newick/r3000014.tree, trees_newick/r3000014_breaks.csv
# ✅ r3000015.trees → trees_newick/r3000015.tree, trees_newick/r3000015_breaks.csv
# ✅ r3000016.trees → trees_newick/r3000016.tree, trees_newick/r3000016_breaks.csv
# ✅ r3000017.trees → trees_newick/r3000017.tree, trees_newick/r3000017_breaks.csv
# ✅ r3000018.trees → trees_newick/r3000018.tree, trees_newick/r3000018_breaks.csv
# ✅ r3000019.trees → trees_newick/r3000019.tree, trees_newick/r3000019_breaks.csv
# ✅ r3000020.trees → trees_newick/r3000020.tree, trees_newick/r3000020_breaks.csv
# ✅ r3000021.trees → trees_newick/r3000021.tree, trees_newick/r3000021_breaks.csv
# ✅ r3000022.trees → trees_newick/r3000022.tree, trees_newick/r3000022_breaks.csv
# ✅ r3000023.trees → trees_newick/r3000023.tree, trees_newick/r3000023_breaks.csv
# ✅ r3000024.trees → trees_newick/r3000024.tree, trees_newick/r3000024_breaks.csv
# ✅ r3000025.trees → trees_newick/r3000025.tree, trees_newick/r3000025_breaks.csv
# ✅ r3000026.trees → trees_newick/r3000026.tree, trees_newick/r3000026_breaks.csv
# ✅ r3000027.trees → trees_newick/r3000027.tree, trees_newick/r3000027_breaks.csv
# ✅ r3000028.trees → trees_newick/r3000028.tree, trees_newick/r3000028_breaks.csv
# ✅ r3000029.trees → trees_newick/r3000029.tree, trees_newick/r3000029_breaks.csv
# ✅ r3000030.trees → trees_newick/r3000030.tree, trees_newick/r3000030_breaks.csv
# ✅ r3000031.trees → trees_newick/r3000031.tree, trees_newick/r3000031_breaks.csv
# ✅ r3000032.trees → trees_newick/r3000032.tree, trees_newick/r3000032_breaks.csv
# ✅ r3000033.trees → trees_newick/r3000033.tree, trees_newick/r3000033_breaks.csv
# ✅ r3000034.trees → trees_newick/r3000034.tree, trees_newick/r3000034_breaks.csv
# ✅ r3000035.trees → trees_newick/r3000035.tree, trees_newick/r3000035_breaks.csv
# ✅ r3000036.trees → trees_newick/r3000036.tree, trees_newick/r3000036_breaks.csv
# ✅ r3000037.trees → trees_newick/r3000037.tree, trees_newick/r3000037_breaks.csv
# ✅ r3000038.trees → trees_newick/r3000038.tree, trees_newick/r3000038_breaks.csv
# ✅ r3000039.trees → trees_newick/r3000039.tree, trees_newick/r3000039_breaks.csv
# ✅ r3000040.trees → trees_newick/r3000040.tree, trees_newick/r3000040_breaks.csv
# ✅ r3000041.trees → trees_newick/r3000041.tree, trees_newick/r3000041_breaks.csv
# ✅ r3000042.trees → trees_newick/r3000042.tree, trees_newick/r3000042_breaks.csv
# ✅ r3000043.trees → trees_newick/r3000043.tree, trees_newick/r3000043_breaks.csv
# ✅ r3000044.trees → trees_newick/r3000044.tree, trees_newick/r3000044_breaks.csv
# ✅ r3000045.trees → trees_newick/r3000045.tree, trees_newick/r3000045_breaks.csv
# ✅ r3000046.trees → trees_newick/r3000046.tree, trees_newick/r3000046_breaks.csv
# ✅ r3000047.trees → trees_newick/r3000047.tree, trees_newick/r3000047_breaks.csv
# ✅ r3000048.trees → trees_newick/r3000048.tree, trees_newick/r3000048_breaks.csv
# ✅ r3000049.trees → trees_newick/r3000049.tree, trees_newick/r3000049_breaks.csv
# ✅ r3000050.trees → trees_newick/r3000050.tree, trees_newick/r3000050_breaks.csv
# ✅ r3000051.trees → trees_newick/r3000051.tree, trees_newick/r3000051_breaks.csv
# ✅ r3000052.trees → trees_newick/r3000052.tree, trees_newick/r3000052_breaks.csv
# ✅ r3000053.trees → trees_newick/r3000053.tree, trees_newick/r3000053_breaks.csv
# ✅ r3000054.trees → trees_newick/r3000054.tree, trees_newick/r3000054_breaks.csv
# ✅ r3000055.trees → trees_newick/r3000055.tree, trees_newick/r3000055_breaks.csv
# ✅ r3000056.trees → trees_newick/r3000056.tree, trees_newick/r3000056_breaks.csv
# ✅ r3000057.trees → trees_newick/r3000057.tree, trees_newick/r3000057_breaks.csv
# ✅ r3000058.trees → trees_newick/r3000058.tree, trees_newick/r3000058_breaks.csv
# ✅ r3000059.trees → trees_newick/r3000059.tree, trees_newick/r3000059_breaks.csv
# ✅ r3000060.trees → trees_newick/r3000060.tree, trees_newick/r3000060_breaks.csv
# ✅ r3000061.trees → trees_newick/r3000061.tree, trees_newick/r3000061_breaks.csv
# ✅ r3000062.trees → trees_newick/r3000062.tree, trees_newick/r3000062_breaks.csv
# ✅ r3000063.trees → trees_newick/r3000063.tree, trees_newick/r3000063_breaks.csv
# ✅ r3000064.trees → trees_newick/r3000064.tree, trees_newick/r3000064_breaks.csv
# ✅ r3000065.trees → trees_newick/r3000065.tree, trees_newick/r3000065_breaks.csv
# ✅ r3000066.trees → trees_newick/r3000066.tree, trees_newick/r3000066_breaks.csv
# ✅ r3000067.trees → trees_newick/r3000067.tree, trees_newick/r3000067_breaks.csv
# ✅ r3000068.trees → trees_newick/r3000068.tree, trees_newick/r3000068_breaks.csv
# ✅ r3000069.trees → trees_newick/r3000069.tree, trees_newick/r3000069_breaks.csv
# ✅ r3000070.trees → trees_newick/r3000070.tree, trees_newick/r3000070_breaks.csv
# ✅ r3000071.trees → trees_newick/r3000071.tree, trees_newick/r3000071_breaks.csv
# ✅ r3000072.trees → trees_newick/r3000072.tree, trees_newick/r3000072_breaks.csv
# ✅ r3000073.trees → trees_newick/r3000073.tree, trees_newick/r3000073_breaks.csv
# ✅ r3000074.trees → trees_newick/r3000074.tree, trees_newick/r3000074_breaks.csv
# ✅ r3000075.trees → trees_newick/r3000075.tree, trees_newick/r3000075_breaks.csv
# ✅ r3000076.trees → trees_newick/r3000076.tree, trees_newick/r3000076_breaks.csv
# ✅ r3000077.trees → trees_newick/r3000077.tree, trees_newick/r3000077_breaks.csv
# ✅ r3000078.trees → trees_newick/r3000078.tree, trees_newick/r3000078_breaks.csv
# ✅ r3000079.trees → trees_newick/r3000079.tree, trees_newick/r3000079_breaks.csv
# ✅ r3000080.trees → trees_newick/r3000080.tree, trees_newick/r3000080_breaks.csv
# ✅ r3000081.trees → trees_newick/r3000081.tree, trees_newick/r3000081_breaks.csv
# ✅ r3000082.trees → trees_newick/r3000082.tree, trees_newick/r3000082_breaks.csv
# ✅ r3000083.trees → trees_newick/r3000083.tree, trees_newick/r3000083_breaks.csv
# ✅ r3000084.trees → trees_newick/r3000084.tree, trees_newick/r3000084_breaks.csv
# ✅ r3000085.trees → trees_newick/r3000085.tree, trees_newick/r3000085_breaks.csv
# ✅ r3000086.trees → trees_newick/r3000086.tree, trees_newick/r3000086_breaks.csv
# ✅ r3000087.trees → trees_newick/r3000087.tree, trees_newick/r3000087_breaks.csv
# ✅ r3000088.trees → trees_newick/r3000088.tree, trees_newick/r3000088_breaks.csv
# ✅ r3000089.trees → trees_newick/r3000089.tree, trees_newick/r3000089_breaks.csv
# ✅ r3000090.trees → trees_newick/r3000090.tree, trees_newick/r3000090_breaks.csv
# ✅ r3000091.trees → trees_newick/r3000091.tree, trees_newick/r3000091_breaks.csv
# ✅ r3000092.trees → trees_newick/r3000092.tree, trees_newick/r3000092_breaks.csv
# ✅ r3000093.trees → trees_newick/r3000093.tree, trees_newick/r3000093_breaks.csv
# ✅ r3000094.trees → trees_newick/r3000094.tree, trees_newick/r3000094_breaks.csv
# ✅ r3000095.trees → trees_newick/r3000095.tree, trees_newick/r3000095_breaks.csv
# ✅ r3000096.trees → trees_newick/r3000096.tree, trees_newick/r3000096_breaks.csv
# ✅ r3000097.trees → trees_newick/r3000097.tree, trees_newick/r3000097_breaks.csv
# ✅ r3000098.trees → trees_newick/r3000098.tree, trees_newick/r3000098_breaks.csv
# ✅ r3000099.trees → trees_newick/r3000099.tree, trees_newick/r3000099_breaks.csv
# ✅ r3000100.trees → trees_newick/r3000100.tree, trees_newick/r3000100_breaks.csv
# ✅ r3000101.trees → trees_newick/r3000101.tree, trees_newick/r3000101_breaks.csv
# ✅ r3000102.trees → trees_newick/r3000102.tree, trees_newick/r3000102_breaks.csv
# ✅ r3000103.trees → trees_newick/r3000103.tree, trees_newick/r3000103_breaks.csv
# ✅ r3000104.trees → trees_newick/r3000104.tree, trees_newick/r3000104_breaks.csv
# ✅ r3000105.trees → trees_newick/r3000105.tree, trees_newick/r3000105_breaks.csv
# ✅ r3000106.trees → trees_newick/r3000106.tree, trees_newick/r3000106_breaks.csv
# ✅ r3000107.trees → trees_newick/r3000107.tree, trees_newick/r3000107_breaks.csv
# ✅ r3000108.trees → trees_newick/r3000108.tree, trees_newick/r3000108_breaks.csv
# ✅ r3000109.trees → trees_newick/r3000109.tree, trees_newick/r3000109_breaks.csv
# ✅ r3000110.trees → trees_newick/r3000110.tree, trees_newick/r3000110_breaks.csv
# ✅ r3000111.trees → trees_newick/r3000111.tree, trees_newick/r3000111_breaks.csv
# ✅ r3000112.trees → trees_newick/r3000112.tree, trees_newick/r3000112_breaks.csv
# ✅ r3000113.trees → trees_newick/r3000113.tree, trees_newick/r3000113_breaks.csv
# ✅ r3000114.trees → trees_newick/r3000114.tree, trees_newick/r3000114_breaks.csv
# ✅ r3000115.trees → trees_newick/r3000115.tree, trees_newick/r3000115_breaks.csv
# ✅ r3000116.trees → trees_newick/r3000116.tree, trees_newick/r3000116_breaks.csv
# ✅ r3000117.trees → trees_newick/r3000117.tree, trees_newick/r3000117_breaks.csv
# ✅ r3000118.trees → trees_newick/r3000118.tree, trees_newick/r3000118_breaks.csv
# ✅ r3000119.trees → trees_newick/r3000119.tree, trees_newick/r3000119_breaks.csv
# ✅ r3000120.trees → trees_newick/r3000120.tree, trees_newick/r3000120_breaks.csv
# ✅ r3000121.trees → trees_newick/r3000121.tree, trees_newick/r3000121_breaks.csv
# ✅ r3000122.trees → trees_newick/r3000122.tree, trees_newick/r3000122_breaks.csv
# ✅ r3000123.trees → trees_newick/r3000123.tree, trees_newick/r3000123_breaks.csv
# ✅ r3000124.trees → trees_newick/r3000124.tree, trees_newick/r3000124_breaks.csv
# ✅ r3000125.trees → trees_newick/r3000125.tree, trees_newick/r3000125_breaks.csv
# ✅ r3000126.trees → trees_newick/r3000126.tree, trees_newick/r3000126_breaks.csv
# ✅ r3000127.trees → trees_newick/r3000127.tree, trees_newick/r3000127_breaks.csv
# ✅ r3000128.trees → trees_newick/r3000128.tree, trees_newick/r3000128_breaks.csv
# ✅ r3000129.trees → trees_newick/r3000129.tree, trees_newick/r3000129_breaks.csv
# ✅ r3000130.trees → trees_newick/r3000130.tree, trees_newick/r3000130_breaks.csv
# ✅ r3000131.trees → trees_newick/r3000131.tree, trees_newick/r3000131_breaks.csv
# ✅ r3000132.trees → trees_newick/r3000132.tree, trees_newick/r3000132_breaks.csv
# ✅ r3000133.trees → trees_newick/r3000133.tree, trees_newick/r3000133_breaks.csv
# ✅ r3000134.trees → trees_newick/r3000134.tree, trees_newick/r3000134_breaks.csv
# ✅ r3000135.trees → trees_newick/r3000135.tree, trees_newick/r3000135_breaks.csv
# ✅ r3000136.trees → trees_newick/r3000136.tree, trees_newick/r3000136_breaks.csv
# ✅ r3000137.trees → trees_newick/r3000137.tree, trees_newick/r3000137_breaks.csv
# ✅ r3000138.trees → trees_newick/r3000138.tree, trees_newick/r3000138_breaks.csv
# ✅ r3000139.trees → trees_newick/r3000139.tree, trees_newick/r3000139_breaks.csv
# ✅ r3000140.trees → trees_newick/r3000140.tree, trees_newick/r3000140_breaks.csv
# ✅ r3000141.trees → trees_newick/r3000141.tree, trees_newick/r3000141_breaks.csv
# ✅ r3000142.trees → trees_newick/r3000142.tree, trees_newick/r3000142_breaks.csv
# ✅ r3000143.trees → trees_newick/r3000143.tree, trees_newick/r3000143_breaks.csv
# ✅ r3000144.trees → trees_newick/r3000144.tree, trees_newick/r3000144_breaks.csv
# ✅ r3000145.trees → trees_newick/r3000145.tree, trees_newick/r3000145_breaks.csv
# ✅ r3000146.trees → trees_newick/r3000146.tree, trees_newick/r3000146_breaks.csv
# ✅ r3000147.trees → trees_newick/r3000147.tree, trees_newick/r3000147_breaks.csv
# ✅ r3000148.trees → trees_newick/r3000148.tree, trees_newick/r3000148_breaks.csv
# ✅ r3000149.trees → trees_newick/r3000149.tree, trees_newick/r3000149_breaks.csv
# ✅ r3000150.trees → trees_newick/r3000150.tree, trees_newick/r3000150_breaks.csv
# ✅ r3000151.trees → trees_newick/r3000151.tree, trees_newick/r3000151_breaks.csv
# ✅ r3000152.trees → trees_newick/r3000152.tree, trees_newick/r3000152_breaks.csv
# ✅ r3000153.trees → trees_newick/r3000153.tree, trees_newick/r3000153_breaks.csv
# ✅ r3000154.trees → trees_newick/r3000154.tree, trees_newick/r3000154_breaks.csv
# ✅ r3000155.trees → trees_newick/r3000155.tree, trees_newick/r3000155_breaks.csv
# ✅ r3000156.trees → trees_newick/r3000156.tree, trees_newick/r3000156_breaks.csv
# ✅ r3000157.trees → trees_newick/r3000157.tree, trees_newick/r3000157_breaks.csv
# ✅ r3000158.trees → trees_newick/r3000158.tree, trees_newick/r3000158_breaks.csv
# ✅ r3000159.trees → trees_newick/r3000159.tree, trees_newick/r3000159_breaks.csv
# ✅ r3000160.trees → trees_newick/r3000160.tree, trees_newick/r3000160_breaks.csv
# ✅ r3000161.trees → trees_newick/r3000161.tree, trees_newick/r3000161_breaks.csv
# ✅ r3000162.trees → trees_newick/r3000162.tree, trees_newick/r3000162_breaks.csv
# ✅ r3000163.trees → trees_newick/r3000163.tree, trees_newick/r3000163_breaks.csv
# ✅ r3000164.trees → trees_newick/r3000164.tree, trees_newick/r3000164_breaks.csv
# ✅ r3000165.trees → trees_newick/r3000165.tree, trees_newick/r3000165_breaks.csv
# ✅ r3000166.trees → trees_newick/r3000166.tree, trees_newick/r3000166_breaks.csv
# ✅ r3000167.trees → trees_newick/r3000167.tree, trees_newick/r3000167_breaks.csv
# ✅ r3000168.trees → trees_newick/r3000168.tree, trees_newick/r3000168_breaks.csv
# ✅ r3000169.trees → trees_newick/r3000169.tree, trees_newick/r3000169_breaks.csv
# ✅ r3000170.trees → trees_newick/r3000170.tree, trees_newick/r3000170_breaks.csv
# ✅ r3000171.trees → trees_newick/r3000171.tree, trees_newick/r3000171_breaks.csv
# ✅ r3000172.trees → trees_newick/r3000172.tree, trees_newick/r3000172_breaks.csv
# ✅ r3000173.trees → trees_newick/r3000173.tree, trees_newick/r3000173_breaks.csv
# ✅ r3000174.trees → trees_newick/r3000174.tree, trees_newick/r3000174_breaks.csv
# ✅ r3000175.trees → trees_newick/r3000175.tree, trees_newick/r3000175_breaks.csv
# ✅ r3000176.trees → trees_newick/r3000176.tree, trees_newick/r3000176_breaks.csv
# ✅ r3000177.trees → trees_newick/r3000177.tree, trees_newick/r3000177_breaks.csv
# ✅ r3000178.trees → trees_newick/r3000178.tree, trees_newick/r3000178_breaks.csv
# ✅ r3000179.trees → trees_newick/r3000179.tree, trees_newick/r3000179_breaks.csv
# ✅ r3000180.trees → trees_newick/r3000180.tree, trees_newick/r3000180_breaks.csv
# ✅ r3000181.trees → trees_newick/r3000181.tree, trees_newick/r3000181_breaks.csv
# ✅ r3000182.trees → trees_newick/r3000182.tree, trees_newick/r3000182_breaks.csv
# ✅ r3000183.trees → trees_newick/r3000183.tree, trees_newick/r3000183_breaks.csv
# ✅ r3000184.trees → trees_newick/r3000184.tree, trees_newick/r3000184_breaks.csv
# ✅ r3000185.trees → trees_newick/r3000185.tree, trees_newick/r3000185_breaks.csv
# ✅ r3000186.trees → trees_newick/r3000186.tree, trees_newick/r3000186_breaks.csv
# ✅ r3000187.trees → trees_newick/r3000187.tree, trees_newick/r3000187_breaks.csv
# ✅ r3000188.trees → trees_newick/r3000188.tree, trees_newick/r3000188_breaks.csv
# ✅ r3000189.trees → trees_newick/r3000189.tree, trees_newick/r3000189_breaks.csv
# ✅ r3000190.trees → trees_newick/r3000190.tree, trees_newick/r3000190_breaks.csv
# ✅ r3000191.trees → trees_newick/r3000191.tree, trees_newick/r3000191_breaks.csv
# ✅ r3000192.trees → trees_newick/r3000192.tree, trees_newick/r3000192_breaks.csv
# ✅ r3000193.trees → trees_newick/r3000193.tree, trees_newick/r3000193_breaks.csv
# ✅ r3000194.trees → trees_newick/r3000194.tree, trees_newick/r3000194_breaks.csv
# ✅ r3000195.trees → trees_newick/r3000195.tree, trees_newick/r3000195_breaks.csv
# ✅ r3000196.trees → trees_newick/r3000196.tree, trees_newick/r3000196_breaks.csv
# ✅ r3000197.trees → trees_newick/r3000197.tree, trees_newick/r3000197_breaks.csv
# ✅ r3000198.trees → trees_newick/r3000198.tree, trees_newick/r3000198_breaks.csv
# ✅ r3000199.trees → trees_newick/r3000199.tree, trees_newick/r3000199_breaks.csv
# ✅ r3010000.trees → trees_newick/r3010000.tree, trees_newick/r3010000_breaks.csv
# ✅ r3010001.trees → trees_newick/r3010001.tree, trees_newick/r3010001_breaks.csv
# ✅ r3010002.trees → trees_newick/r3010002.tree, trees_newick/r3010002_breaks.csv
# ✅ r3010003.trees → trees_newick/r3010003.tree, trees_newick/r3010003_breaks.csv
# ✅ r3010004.trees → trees_newick/r3010004.tree, trees_newick/r3010004_breaks.csv
# ✅ r3010005.trees → trees_newick/r3010005.tree, trees_newick/r3010005_breaks.csv
# ✅ r3010006.trees → trees_newick/r3010006.tree, trees_newick/r3010006_breaks.csv
# ✅ r3010007.trees → trees_newick/r3010007.tree, trees_newick/r3010007_breaks.csv
# ✅ r3010008.trees → trees_newick/r3010008.tree, trees_newick/r3010008_breaks.csv
# ✅ r3010009.trees → trees_newick/r3010009.tree, trees_newick/r3010009_breaks.csv
# ✅ r3010010.trees → trees_newick/r3010010.tree, trees_newick/r3010010_breaks.csv
# ✅ r3010011.trees → trees_newick/r3010011.tree, trees_newick/r3010011_breaks.csv
# ✅ r3010012.trees → trees_newick/r3010012.tree, trees_newick/r3010012_breaks.csv
# ✅ r3010013.trees → trees_newick/r3010013.tree, trees_newick/r3010013_breaks.csv
# ✅ r3010014.trees → trees_newick/r3010014.tree, trees_newick/r3010014_breaks.csv
# ✅ r3010015.trees → trees_newick/r3010015.tree, trees_newick/r3010015_breaks.csv
# ✅ r3010016.trees → trees_newick/r3010016.tree, trees_newick/r3010016_breaks.csv
# ✅ r3010017.trees → trees_newick/r3010017.tree, trees_newick/r3010017_breaks.csv
# ✅ r3010018.trees → trees_newick/r3010018.tree, trees_newick/r3010018_breaks.csv
# ✅ r3010019.trees → trees_newick/r3010019.tree, trees_newick/r3010019_breaks.csv
# ✅ r3010020.trees → trees_newick/r3010020.tree, trees_newick/r3010020_breaks.csv
# ✅ r3010021.trees → trees_newick/r3010021.tree, trees_newick/r3010021_breaks.csv
# ✅ r3010022.trees → trees_newick/r3010022.tree, trees_newick/r3010022_breaks.csv
# ✅ r3010023.trees → trees_newick/r3010023.tree, trees_newick/r3010023_breaks.csv
# ✅ r3010024.trees → trees_newick/r3010024.tree, trees_newick/r3010024_breaks.csv
# ✅ r3010025.trees → trees_newick/r3010025.tree, trees_newick/r3010025_breaks.csv
# ✅ r3010026.trees → trees_newick/r3010026.tree, trees_newick/r3010026_breaks.csv
# ✅ r3010027.trees → trees_newick/r3010027.tree, trees_newick/r3010027_breaks.csv
# ✅ r3010028.trees → trees_newick/r3010028.tree, trees_newick/r3010028_breaks.csv
# ✅ r3010029.trees → trees_newick/r3010029.tree, trees_newick/r3010029_breaks.csv
# ✅ r3010030.trees → trees_newick/r3010030.tree, trees_newick/r3010030_breaks.csv
# ✅ r3010031.trees → trees_newick/r3010031.tree, trees_newick/r3010031_breaks.csv
# ✅ r3010032.trees → trees_newick/r3010032.tree, trees_newick/r3010032_breaks.csv
# ✅ r3010033.trees → trees_newick/r3010033.tree, trees_newick/r3010033_breaks.csv
# ✅ r3010034.trees → trees_newick/r3010034.tree, trees_newick/r3010034_breaks.csv
# ✅ r3010035.trees → trees_newick/r3010035.tree, trees_newick/r3010035_breaks.csv
# ✅ r3010036.trees → trees_newick/r3010036.tree, trees_newick/r3010036_breaks.csv
# ✅ r3010037.trees → trees_newick/r3010037.tree, trees_newick/r3010037_breaks.csv
# ✅ r3010038.trees → trees_newick/r3010038.tree, trees_newick/r3010038_breaks.csv
# ✅ r3010039.trees → trees_newick/r3010039.tree, trees_newick/r3010039_breaks.csv
# ✅ r3010040.trees → trees_newick/r3010040.tree, trees_newick/r3010040_breaks.csv
# ✅ r3010041.trees → trees_newick/r3010041.tree, trees_newick/r3010041_breaks.csv
# ✅ r3010042.trees → trees_newick/r3010042.tree, trees_newick/r3010042_breaks.csv
# ✅ r3010043.trees → trees_newick/r3010043.tree, trees_newick/r3010043_breaks.csv
# ✅ r3010044.trees → trees_newick/r3010044.tree, trees_newick/r3010044_breaks.csv
# ✅ r3010045.trees → trees_newick/r3010045.tree, trees_newick/r3010045_breaks.csv
# ✅ r3010046.trees → trees_newick/r3010046.tree, trees_newick/r3010046_breaks.csv
# ✅ r3010047.trees → trees_newick/r3010047.tree, trees_newick/r3010047_breaks.csv
# ✅ r3010048.trees → trees_newick/r3010048.tree, trees_newick/r3010048_breaks.csv
# ✅ r3010049.trees → trees_newick/r3010049.tree, trees_newick/r3010049_breaks.csv
# ✅ r3010050.trees → trees_newick/r3010050.tree, trees_newick/r3010050_breaks.csv
# ✅ r3010051.trees → trees_newick/r3010051.tree, trees_newick/r3010051_breaks.csv
# ✅ r3010052.trees → trees_newick/r3010052.tree, trees_newick/r3010052_breaks.csv
# ✅ r3010053.trees → trees_newick/r3010053.tree, trees_newick/r3010053_breaks.csv
# ✅ r3010054.trees → trees_newick/r3010054.tree, trees_newick/r3010054_breaks.csv
# ✅ r3010055.trees → trees_newick/r3010055.tree, trees_newick/r3010055_breaks.csv
# ✅ r3010056.trees → trees_newick/r3010056.tree, trees_newick/r3010056_breaks.csv
# ✅ r3010057.trees → trees_newick/r3010057.tree, trees_newick/r3010057_breaks.csv
# ✅ r3010058.trees → trees_newick/r3010058.tree, trees_newick/r3010058_breaks.csv
# ✅ r3010059.trees → trees_newick/r3010059.tree, trees_newick/r3010059_breaks.csv
# ✅ r3010060.trees → trees_newick/r3010060.tree, trees_newick/r3010060_breaks.csv
# ✅ r3010061.trees → trees_newick/r3010061.tree, trees_newick/r3010061_breaks.csv
# ✅ r3010062.trees → trees_newick/r3010062.tree, trees_newick/r3010062_breaks.csv
# ✅ r3010063.trees → trees_newick/r3010063.tree, trees_newick/r3010063_breaks.csv
# ✅ r3010064.trees → trees_newick/r3010064.tree, trees_newick/r3010064_breaks.csv
# ✅ r3010065.trees → trees_newick/r3010065.tree, trees_newick/r3010065_breaks.csv
# ✅ r3010066.trees → trees_newick/r3010066.tree, trees_newick/r3010066_breaks.csv
# ✅ r3010067.trees → trees_newick/r3010067.tree, trees_newick/r3010067_breaks.csv
# ✅ r3010068.trees → trees_newick/r3010068.tree, trees_newick/r3010068_breaks.csv
# ✅ r3010069.trees → trees_newick/r3010069.tree, trees_newick/r3010069_breaks.csv
# ✅ r3010070.trees → trees_newick/r3010070.tree, trees_newick/r3010070_breaks.csv
# ✅ r3010071.trees → trees_newick/r3010071.tree, trees_newick/r3010071_breaks.csv
# ✅ r3010072.trees → trees_newick/r3010072.tree, trees_newick/r3010072_breaks.csv
# ✅ r3010073.trees → trees_newick/r3010073.tree, trees_newick/r3010073_breaks.csv
# ✅ r3010074.trees → trees_newick/r3010074.tree, trees_newick/r3010074_breaks.csv
# ✅ r3010075.trees → trees_newick/r3010075.tree, trees_newick/r3010075_breaks.csv
# ✅ r3010076.trees → trees_newick/r3010076.tree, trees_newick/r3010076_breaks.csv
# ✅ r3010077.trees → trees_newick/r3010077.tree, trees_newick/r3010077_breaks.csv
# ✅ r3010078.trees → trees_newick/r3010078.tree, trees_newick/r3010078_breaks.csv
# ✅ r3010079.trees → trees_newick/r3010079.tree, trees_newick/r3010079_breaks.csv
# ✅ r3010080.trees → trees_newick/r3010080.tree, trees_newick/r3010080_breaks.csv
# ✅ r3010081.trees → trees_newick/r3010081.tree, trees_newick/r3010081_breaks.csv
# ✅ r3010082.trees → trees_newick/r3010082.tree, trees_newick/r3010082_breaks.csv
# ✅ r3010083.trees → trees_newick/r3010083.tree, trees_newick/r3010083_breaks.csv
# ✅ r3010084.trees → trees_newick/r3010084.tree, trees_newick/r3010084_breaks.csv
# ✅ r3010085.trees → trees_newick/r3010085.tree, trees_newick/r3010085_breaks.csv
# ✅ r3010086.trees → trees_newick/r3010086.tree, trees_newick/r3010086_breaks.csv
# ✅ r3010087.trees → trees_newick/r3010087.tree, trees_newick/r3010087_breaks.csv
# ✅ r3010088.trees → trees_newick/r3010088.tree, trees_newick/r3010088_breaks.csv
# ✅ r3010089.trees → trees_newick/r3010089.tree, trees_newick/r3010089_breaks.csv
# ✅ r3010090.trees → trees_newick/r3010090.tree, trees_newick/r3010090_breaks.csv
# ✅ r3010091.trees → trees_newick/r3010091.tree, trees_newick/r3010091_breaks.csv
# ✅ r3010092.trees → trees_newick/r3010092.tree, trees_newick/r3010092_breaks.csv
# ✅ r3010093.trees → trees_newick/r3010093.tree, trees_newick/r3010093_breaks.csv
# ✅ r3010094.trees → trees_newick/r3010094.tree, trees_newick/r3010094_breaks.csv
# ✅ r3010095.trees → trees_newick/r3010095.tree, trees_newick/r3010095_breaks.csv
# ✅ r3010096.trees → trees_newick/r3010096.tree, trees_newick/r3010096_breaks.csv
# ✅ r3010097.trees → trees_newick/r3010097.tree, trees_newick/r3010097_breaks.csv
# ✅ r3010098.trees → trees_newick/r3010098.tree, trees_newick/r3010098_breaks.csv
# ✅ r3010099.trees → trees_newick/r3010099.tree, trees_newick/r3010099_breaks.csv
# ✅ r3020000.trees → trees_newick/r3020000.tree, trees_newick/r3020000_breaks.csv
# ✅ r3020001.trees → trees_newick/r3020001.tree, trees_newick/r3020001_breaks.csv
# ✅ r3020002.trees → trees_newick/r3020002.tree, trees_newick/r3020002_breaks.csv
# ✅ r3020003.trees → trees_newick/r3020003.tree, trees_newick/r3020003_breaks.csv
# ✅ r3020004.trees → trees_newick/r3020004.tree, trees_newick/r3020004_breaks.csv
# ✅ r3020005.trees → trees_newick/r3020005.tree, trees_newick/r3020005_breaks.csv
# ✅ r3020006.trees → trees_newick/r3020006.tree, trees_newick/r3020006_breaks.csv
# ✅ r3020007.trees → trees_newick/r3020007.tree, trees_newick/r3020007_breaks.csv
# ✅ r3020008.trees → trees_newick/r3020008.tree, trees_newick/r3020008_breaks.csv
# ✅ r3020009.trees → trees_newick/r3020009.tree, trees_newick/r3020009_breaks.csv
# ✅ r3020010.trees → trees_newick/r3020010.tree, trees_newick/r3020010_breaks.csv
# ✅ r3020011.trees → trees_newick/r3020011.tree, trees_newick/r3020011_breaks.csv
# ✅ r3020012.trees → trees_newick/r3020012.tree, trees_newick/r3020012_breaks.csv
# ✅ r3020013.trees → trees_newick/r3020013.tree, trees_newick/r3020013_breaks.csv
# ✅ r3020014.trees → trees_newick/r3020014.tree, trees_newick/r3020014_breaks.csv
# ✅ r3020015.trees → trees_newick/r3020015.tree, trees_newick/r3020015_breaks.csv
# ✅ r3020016.trees → trees_newick/r3020016.tree, trees_newick/r3020016_breaks.csv
# ✅ r3020017.trees → trees_newick/r3020017.tree, trees_newick/r3020017_breaks.csv
# ✅ r3020018.trees → trees_newick/r3020018.tree, trees_newick/r3020018_breaks.csv
# ✅ r3020019.trees → trees_newick/r3020019.tree, trees_newick/r3020019_breaks.csv
# ✅ r3020020.trees → trees_newick/r3020020.tree, trees_newick/r3020020_breaks.csv
# ✅ r3020021.trees → trees_newick/r3020021.tree, trees_newick/r3020021_breaks.csv
# ✅ r3020022.trees → trees_newick/r3020022.tree, trees_newick/r3020022_breaks.csv
# ✅ r3020023.trees → trees_newick/r3020023.tree, trees_newick/r3020023_breaks.csv
# ✅ r3020024.trees → trees_newick/r3020024.tree, trees_newick/r3020024_breaks.csv
# ✅ r3020025.trees → trees_newick/r3020025.tree, trees_newick/r3020025_breaks.csv
# ✅ r3020026.trees → trees_newick/r3020026.tree, trees_newick/r3020026_breaks.csv
# ✅ r3020027.trees → trees_newick/r3020027.tree, trees_newick/r3020027_breaks.csv
# ✅ r3020028.trees → trees_newick/r3020028.tree, trees_newick/r3020028_breaks.csv
# ✅ r3020029.trees → trees_newick/r3020029.tree, trees_newick/r3020029_breaks.csv
# ✅ r3020030.trees → trees_newick/r3020030.tree, trees_newick/r3020030_breaks.csv
# ✅ r3020031.trees → trees_newick/r3020031.tree, trees_newick/r3020031_breaks.csv
# ✅ r3020032.trees → trees_newick/r3020032.tree, trees_newick/r3020032_breaks.csv
# ✅ r3020033.trees → trees_newick/r3020033.tree, trees_newick/r3020033_breaks.csv
# ✅ r3020034.trees → trees_newick/r3020034.tree, trees_newick/r3020034_breaks.csv
# ✅ r3020035.trees → trees_newick/r3020035.tree, trees_newick/r3020035_breaks.csv
# ✅ r3020036.trees → trees_newick/r3020036.tree, trees_newick/r3020036_breaks.csv
# ✅ r3020037.trees → trees_newick/r3020037.tree, trees_newick/r3020037_breaks.csv
# ✅ r3020038.trees → trees_newick/r3020038.tree, trees_newick/r3020038_breaks.csv
# ✅ r3020039.trees → trees_newick/r3020039.tree, trees_newick/r3020039_breaks.csv
# ✅ r3020040.trees → trees_newick/r3020040.tree, trees_newick/r3020040_breaks.csv
# ✅ r3020041.trees → trees_newick/r3020041.tree, trees_newick/r3020041_breaks.csv
# ✅ r3020042.trees → trees_newick/r3020042.tree, trees_newick/r3020042_breaks.csv
# ✅ r3020043.trees → trees_newick/r3020043.tree, trees_newick/r3020043_breaks.csv
# ✅ r3020044.trees → trees_newick/r3020044.tree, trees_newick/r3020044_breaks.csv
# ✅ r3020045.trees → trees_newick/r3020045.tree, trees_newick/r3020045_breaks.csv
# ✅ r3020046.trees → trees_newick/r3020046.tree, trees_newick/r3020046_breaks.csv
# ✅ r3020047.trees → trees_newick/r3020047.tree, trees_newick/r3020047_breaks.csv
# ✅ r3020048.trees → trees_newick/r3020048.tree, trees_newick/r3020048_breaks.csv
# ✅ r3020049.trees → trees_newick/r3020049.tree, trees_newick/r3020049_breaks.csv
# ✅ r3020050.trees → trees_newick/r3020050.tree, trees_newick/r3020050_breaks.csv
# ✅ r3020051.trees → trees_newick/r3020051.tree, trees_newick/r3020051_breaks.csv
# ✅ r3020052.trees → trees_newick/r3020052.tree, trees_newick/r3020052_breaks.csv
# ✅ r3020053.trees → trees_newick/r3020053.tree, trees_newick/r3020053_breaks.csv
# ✅ r3020054.trees → trees_newick/r3020054.tree, trees_newick/r3020054_breaks.csv
# ✅ r3020055.trees → trees_newick/r3020055.tree, trees_newick/r3020055_breaks.csv
# ✅ r3020056.trees → trees_newick/r3020056.tree, trees_newick/r3020056_breaks.csv
# ✅ r3020057.trees → trees_newick/r3020057.tree, trees_newick/r3020057_breaks.csv
# ✅ r3020058.trees → trees_newick/r3020058.tree, trees_newick/r3020058_breaks.csv
# ✅ r3020059.trees → trees_newick/r3020059.tree, trees_newick/r3020059_breaks.csv
# ✅ r3020060.trees → trees_newick/r3020060.tree, trees_newick/r3020060_breaks.csv
# ✅ r3020061.trees → trees_newick/r3020061.tree, trees_newick/r3020061_breaks.csv
# ✅ r3020062.trees → trees_newick/r3020062.tree, trees_newick/r3020062_breaks.csv
# ✅ r3020063.trees → trees_newick/r3020063.tree, trees_newick/r3020063_breaks.csv
# ✅ r3020064.trees → trees_newick/r3020064.tree, trees_newick/r3020064_breaks.csv
# ✅ r3020065.trees → trees_newick/r3020065.tree, trees_newick/r3020065_breaks.csv
# ✅ r3020066.trees → trees_newick/r3020066.tree, trees_newick/r3020066_breaks.csv
# ✅ r3020067.trees → trees_newick/r3020067.tree, trees_newick/r3020067_breaks.csv
# ✅ r3020068.trees → trees_newick/r3020068.tree, trees_newick/r3020068_breaks.csv
# ✅ r3020069.trees → trees_newick/r3020069.tree, trees_newick/r3020069_breaks.csv
# ✅ r3020070.trees → trees_newick/r3020070.tree, trees_newick/r3020070_breaks.csv
# ✅ r3020071.trees → trees_newick/r3020071.tree, trees_newick/r3020071_breaks.csv
# ✅ r3020072.trees → trees_newick/r3020072.tree, trees_newick/r3020072_breaks.csv
# ✅ r3020073.trees → trees_newick/r3020073.tree, trees_newick/r3020073_breaks.csv
# ✅ r3020074.trees → trees_newick/r3020074.tree, trees_newick/r3020074_breaks.csv
# ✅ r3020075.trees → trees_newick/r3020075.tree, trees_newick/r3020075_breaks.csv
# ✅ r3020076.trees → trees_newick/r3020076.tree, trees_newick/r3020076_breaks.csv
# ✅ r3020077.trees → trees_newick/r3020077.tree, trees_newick/r3020077_breaks.csv
# ✅ r3020078.trees → trees_newick/r3020078.tree, trees_newick/r3020078_breaks.csv
# ✅ r3020079.trees → trees_newick/r3020079.tree, trees_newick/r3020079_breaks.csv
# ✅ r3020080.trees → trees_newick/r3020080.tree, trees_newick/r3020080_breaks.csv
# ✅ r3020081.trees → trees_newick/r3020081.tree, trees_newick/r3020081_breaks.csv
# ✅ r3020082.trees → trees_newick/r3020082.tree, trees_newick/r3020082_breaks.csv
# ✅ r3020083.trees → trees_newick/r3020083.tree, trees_newick/r3020083_breaks.csv
# ✅ r3020084.trees → trees_newick/r3020084.tree, trees_newick/r3020084_breaks.csv
# ✅ r3020085.trees → trees_newick/r3020085.tree, trees_newick/r3020085_breaks.csv
# ✅ r3020086.trees → trees_newick/r3020086.tree, trees_newick/r3020086_breaks.csv
# ✅ r3020087.trees → trees_newick/r3020087.tree, trees_newick/r3020087_breaks.csv
# ✅ r3020088.trees → trees_newick/r3020088.tree, trees_newick/r3020088_breaks.csv
# ✅ r3020089.trees → trees_newick/r3020089.tree, trees_newick/r3020089_breaks.csv
# ✅ r3020090.trees → trees_newick/r3020090.tree, trees_newick/r3020090_breaks.csv
# ✅ r3020091.trees → trees_newick/r3020091.tree, trees_newick/r3020091_breaks.csv
# ✅ r3020092.trees → trees_newick/r3020092.tree, trees_newick/r3020092_breaks.csv
# ✅ r3020093.trees → trees_newick/r3020093.tree, trees_newick/r3020093_breaks.csv
# ✅ r3020094.trees → trees_newick/r3020094.tree, trees_newick/r3020094_breaks.csv
# ✅ r3020095.trees → trees_newick/r3020095.tree, trees_newick/r3020095_breaks.csv
# ✅ r3020096.trees → trees_newick/r3020096.tree, trees_newick/r3020096_breaks.csv
# ✅ r3020097.trees → trees_newick/r3020097.tree, trees_newick/r3020097_breaks.csv
# ✅ r3020098.trees → trees_newick/r3020098.tree, trees_newick/r3020098_breaks.csv
# ✅ r3020099.trees → trees_newick/r3020099.tree, trees_newick/r3020099_breaks.csv
# ✅ r3030000.trees → trees_newick/r3030000.tree, trees_newick/r3030000_breaks.csv
# ✅ r3030001.trees → trees_newick/r3030001.tree, trees_newick/r3030001_breaks.csv
# ✅ r3030002.trees → trees_newick/r3030002.tree, trees_newick/r3030002_breaks.csv
# ✅ r3030003.trees → trees_newick/r3030003.tree, trees_newick/r3030003_breaks.csv
# ✅ r3030004.trees → trees_newick/r3030004.tree, trees_newick/r3030004_breaks.csv
# ✅ r3030005.trees → trees_newick/r3030005.tree, trees_newick/r3030005_breaks.csv
# ✅ r3030006.trees → trees_newick/r3030006.tree, trees_newick/r3030006_breaks.csv
# ✅ r3030007.trees → trees_newick/r3030007.tree, trees_newick/r3030007_breaks.csv
# ✅ r3030008.trees → trees_newick/r3030008.tree, trees_newick/r3030008_breaks.csv
# ✅ r3030009.trees → trees_newick/r3030009.tree, trees_newick/r3030009_breaks.csv
# ✅ r3030010.trees → trees_newick/r3030010.tree, trees_newick/r3030010_breaks.csv
# ✅ r3030011.trees → trees_newick/r3030011.tree, trees_newick/r3030011_breaks.csv
# ✅ r3030012.trees → trees_newick/r3030012.tree, trees_newick/r3030012_breaks.csv
# ✅ r3030013.trees → trees_newick/r3030013.tree, trees_newick/r3030013_breaks.csv
# ✅ r3030014.trees → trees_newick/r3030014.tree, trees_newick/r3030014_breaks.csv
# ✅ r3030015.trees → trees_newick/r3030015.tree, trees_newick/r3030015_breaks.csv
# ✅ r3030016.trees → trees_newick/r3030016.tree, trees_newick/r3030016_breaks.csv
# ✅ r3030017.trees → trees_newick/r3030017.tree, trees_newick/r3030017_breaks.csv
# ✅ r3030018.trees → trees_newick/r3030018.tree, trees_newick/r3030018_breaks.csv
# ✅ r3030019.trees → trees_newick/r3030019.tree, trees_newick/r3030019_breaks.csv
# ✅ r3030020.trees → trees_newick/r3030020.tree, trees_newick/r3030020_breaks.csv
# ✅ r3030021.trees → trees_newick/r3030021.tree, trees_newick/r3030021_breaks.csv
# ✅ r3030022.trees → trees_newick/r3030022.tree, trees_newick/r3030022_breaks.csv
# ✅ r3030023.trees → trees_newick/r3030023.tree, trees_newick/r3030023_breaks.csv
# ✅ r3030024.trees → trees_newick/r3030024.tree, trees_newick/r3030024_breaks.csv
# ✅ r3030025.trees → trees_newick/r3030025.tree, trees_newick/r3030025_breaks.csv
# ✅ r3030026.trees → trees_newick/r3030026.tree, trees_newick/r3030026_breaks.csv
# ✅ r3030027.trees → trees_newick/r3030027.tree, trees_newick/r3030027_breaks.csv
# ✅ r3030028.trees → trees_newick/r3030028.tree, trees_newick/r3030028_breaks.csv
# ✅ r3030029.trees → trees_newick/r3030029.tree, trees_newick/r3030029_breaks.csv
# ✅ r3030030.trees → trees_newick/r3030030.tree, trees_newick/r3030030_breaks.csv
# ✅ r3030031.trees → trees_newick/r3030031.tree, trees_newick/r3030031_breaks.csv
# ✅ r3030032.trees → trees_newick/r3030032.tree, trees_newick/r3030032_breaks.csv
# ✅ r3030033.trees → trees_newick/r3030033.tree, trees_newick/r3030033_breaks.csv
# ✅ r3030034.trees → trees_newick/r3030034.tree, trees_newick/r3030034_breaks.csv
# ✅ r3030035.trees → trees_newick/r3030035.tree, trees_newick/r3030035_breaks.csv
# ✅ r3030036.trees → trees_newick/r3030036.tree, trees_newick/r3030036_breaks.csv
# ✅ r3030037.trees → trees_newick/r3030037.tree, trees_newick/r3030037_breaks.csv
# ✅ r3030038.trees → trees_newick/r3030038.tree, trees_newick/r3030038_breaks.csv
# ✅ r3030039.trees → trees_newick/r3030039.tree, trees_newick/r3030039_breaks.csv
# ✅ r3030040.trees → trees_newick/r3030040.tree, trees_newick/r3030040_breaks.csv
# ✅ r3030041.trees → trees_newick/r3030041.tree, trees_newick/r3030041_breaks.csv
# ✅ r3030042.trees → trees_newick/r3030042.tree, trees_newick/r3030042_breaks.csv
# ✅ r3030043.trees → trees_newick/r3030043.tree, trees_newick/r3030043_breaks.csv
# ✅ r3030044.trees → trees_newick/r3030044.tree, trees_newick/r3030044_breaks.csv
# ✅ r3030045.trees → trees_newick/r3030045.tree, trees_newick/r3030045_breaks.csv
# ✅ r3030046.trees → trees_newick/r3030046.tree, trees_newick/r3030046_breaks.csv
# ✅ r3030047.trees → trees_newick/r3030047.tree, trees_newick/r3030047_breaks.csv
# ✅ r3030048.trees → trees_newick/r3030048.tree, trees_newick/r3030048_breaks.csv
# ✅ r3030049.trees → trees_newick/r3030049.tree, trees_newick/r3030049_breaks.csv
# ✅ r3030050.trees → trees_newick/r3030050.tree, trees_newick/r3030050_breaks.csv
# ✅ r3030051.trees → trees_newick/r3030051.tree, trees_newick/r3030051_breaks.csv
# ✅ r3030052.trees → trees_newick/r3030052.tree, trees_newick/r3030052_breaks.csv
# ✅ r3030053.trees → trees_newick/r3030053.tree, trees_newick/r3030053_breaks.csv
# ✅ r3030054.trees → trees_newick/r3030054.tree, trees_newick/r3030054_breaks.csv
# ✅ r3030055.trees → trees_newick/r3030055.tree, trees_newick/r3030055_breaks.csv
# ✅ r3030056.trees → trees_newick/r3030056.tree, trees_newick/r3030056_breaks.csv
# ✅ r3030057.trees → trees_newick/r3030057.tree, trees_newick/r3030057_breaks.csv
# ✅ r3030058.trees → trees_newick/r3030058.tree, trees_newick/r3030058_breaks.csv
# ✅ r3030059.trees → trees_newick/r3030059.tree, trees_newick/r3030059_breaks.csv
# ✅ r3030060.trees → trees_newick/r3030060.tree, trees_newick/r3030060_breaks.csv
# ✅ r3030061.trees → trees_newick/r3030061.tree, trees_newick/r3030061_breaks.csv
# ✅ r3030062.trees → trees_newick/r3030062.tree, trees_newick/r3030062_breaks.csv
# ✅ r3030063.trees → trees_newick/r3030063.tree, trees_newick/r3030063_breaks.csv
# ✅ r3030064.trees → trees_newick/r3030064.tree, trees_newick/r3030064_breaks.csv
# ✅ r3030065.trees → trees_newick/r3030065.tree, trees_newick/r3030065_breaks.csv
# ✅ r3030066.trees → trees_newick/r3030066.tree, trees_newick/r3030066_breaks.csv
# ✅ r3030067.trees → trees_newick/r3030067.tree, trees_newick/r3030067_breaks.csv
# ✅ r3030068.trees → trees_newick/r3030068.tree, trees_newick/r3030068_breaks.csv
# ✅ r3030069.trees → trees_newick/r3030069.tree, trees_newick/r3030069_breaks.csv
# ✅ r3030070.trees → trees_newick/r3030070.tree, trees_newick/r3030070_breaks.csv
# ✅ r3030071.trees → trees_newick/r3030071.tree, trees_newick/r3030071_breaks.csv
# ✅ r3030072.trees → trees_newick/r3030072.tree, trees_newick/r3030072_breaks.csv
# ✅ r3030073.trees → trees_newick/r3030073.tree, trees_newick/r3030073_breaks.csv
# ✅ r3030074.trees → trees_newick/r3030074.tree, trees_newick/r3030074_breaks.csv
# ✅ r3030075.trees → trees_newick/r3030075.tree, trees_newick/r3030075_breaks.csv
# ✅ r3030076.trees → trees_newick/r3030076.tree, trees_newick/r3030076_breaks.csv
# ✅ r3030077.trees → trees_newick/r3030077.tree, trees_newick/r3030077_breaks.csv
# ✅ r3030078.trees → trees_newick/r3030078.tree, trees_newick/r3030078_breaks.csv
# ✅ r3030079.trees → trees_newick/r3030079.tree, trees_newick/r3030079_breaks.csv
# ✅ r3030080.trees → trees_newick/r3030080.tree, trees_newick/r3030080_breaks.csv
# ✅ r3030081.trees → trees_newick/r3030081.tree, trees_newick/r3030081_breaks.csv
# ✅ r3030082.trees → trees_newick/r3030082.tree, trees_newick/r3030082_breaks.csv
# ✅ r3030083.trees → trees_newick/r3030083.tree, trees_newick/r3030083_breaks.csv
# ✅ r3030084.trees → trees_newick/r3030084.tree, trees_newick/r3030084_breaks.csv
# ✅ r3030085.trees → trees_newick/r3030085.tree, trees_newick/r3030085_breaks.csv
# ✅ r3030086.trees → trees_newick/r3030086.tree, trees_newick/r3030086_breaks.csv
# ✅ r3030087.trees → trees_newick/r3030087.tree, trees_newick/r3030087_breaks.csv
# ✅ r3030088.trees → trees_newick/r3030088.tree, trees_newick/r3030088_breaks.csv
# ✅ r3030089.trees → trees_newick/r3030089.tree, trees_newick/r3030089_breaks.csv
# ✅ r3030090.trees → trees_newick/r3030090.tree, trees_newick/r3030090_breaks.csv
# ✅ r3030091.trees → trees_newick/r3030091.tree, trees_newick/r3030091_breaks.csv
# ✅ r3030092.trees → trees_newick/r3030092.tree, trees_newick/r3030092_breaks.csv
# ✅ r3030093.trees → trees_newick/r3030093.tree, trees_newick/r3030093_breaks.csv
# ✅ r3030094.trees → trees_newick/r3030094.tree, trees_newick/r3030094_breaks.csv
# ✅ r3030095.trees → trees_newick/r3030095.tree, trees_newick/r3030095_breaks.csv
# ✅ r3030096.trees → trees_newick/r3030096.tree, trees_newick/r3030096_breaks.csv
# ✅ r3030097.trees → trees_newick/r3030097.tree, trees_newick/r3030097_breaks.csv
# ✅ r3030098.trees → trees_newick/r3030098.tree, trees_newick/r3030098_breaks.csv
# ✅ r3030099.trees → trees_newick/r3030099.tree, trees_newick/r3030099_breaks.csv
# ✅ r3040000.trees → trees_newick/r3040000.tree, trees_newick/r3040000_breaks.csv
# ✅ r3040001.trees → trees_newick/r3040001.tree, trees_newick/r3040001_breaks.csv
# ✅ r3040002.trees → trees_newick/r3040002.tree, trees_newick/r3040002_breaks.csv
# ✅ r3040003.trees → trees_newick/r3040003.tree, trees_newick/r3040003_breaks.csv
# ✅ r3040004.trees → trees_newick/r3040004.tree, trees_newick/r3040004_breaks.csv
# ✅ r3040005.trees → trees_newick/r3040005.tree, trees_newick/r3040005_breaks.csv
# ✅ r3040006.trees → trees_newick/r3040006.tree, trees_newick/r3040006_breaks.csv
# ✅ r3040007.trees → trees_newick/r3040007.tree, trees_newick/r3040007_breaks.csv
# ✅ r3040008.trees → trees_newick/r3040008.tree, trees_newick/r3040008_breaks.csv
# ✅ r3040009.trees → trees_newick/r3040009.tree, trees_newick/r3040009_breaks.csv
# ✅ r3040010.trees → trees_newick/r3040010.tree, trees_newick/r3040010_breaks.csv
# ✅ r3040011.trees → trees_newick/r3040011.tree, trees_newick/r3040011_breaks.csv
# ✅ r3040012.trees → trees_newick/r3040012.tree, trees_newick/r3040012_breaks.csv
# ✅ r3040013.trees → trees_newick/r3040013.tree, trees_newick/r3040013_breaks.csv
# ✅ r3040014.trees → trees_newick/r3040014.tree, trees_newick/r3040014_breaks.csv
# ✅ r3040015.trees → trees_newick/r3040015.tree, trees_newick/r3040015_breaks.csv
# ✅ r3040016.trees → trees_newick/r3040016.tree, trees_newick/r3040016_breaks.csv
# ✅ r3040017.trees → trees_newick/r3040017.tree, trees_newick/r3040017_breaks.csv
# ✅ r3040018.trees → trees_newick/r3040018.tree, trees_newick/r3040018_breaks.csv
# ✅ r3040019.trees → trees_newick/r3040019.tree, trees_newick/r3040019_breaks.csv
# ✅ r3040020.trees → trees_newick/r3040020.tree, trees_newick/r3040020_breaks.csv
# ✅ r3040021.trees → trees_newick/r3040021.tree, trees_newick/r3040021_breaks.csv
# ✅ r3040022.trees → trees_newick/r3040022.tree, trees_newick/r3040022_breaks.csv
# ✅ r3040023.trees → trees_newick/r3040023.tree, trees_newick/r3040023_breaks.csv
# ✅ r3040024.trees → trees_newick/r3040024.tree, trees_newick/r3040024_breaks.csv
# ✅ r3040025.trees → trees_newick/r3040025.tree, trees_newick/r3040025_breaks.csv
# ✅ r3040026.trees → trees_newick/r3040026.tree, trees_newick/r3040026_breaks.csv
# ✅ r3040027.trees → trees_newick/r3040027.tree, trees_newick/r3040027_breaks.csv
# ✅ r3040028.trees → trees_newick/r3040028.tree, trees_newick/r3040028_breaks.csv
# ✅ r3040029.trees → trees_newick/r3040029.tree, trees_newick/r3040029_breaks.csv
# ✅ r3040030.trees → trees_newick/r3040030.tree, trees_newick/r3040030_breaks.csv
# ✅ r3040031.trees → trees_newick/r3040031.tree, trees_newick/r3040031_breaks.csv
# ✅ r3040032.trees → trees_newick/r3040032.tree, trees_newick/r3040032_breaks.csv
# ✅ r3040033.trees → trees_newick/r3040033.tree, trees_newick/r3040033_breaks.csv
# ✅ r3040034.trees → trees_newick/r3040034.tree, trees_newick/r3040034_breaks.csv
# ✅ r3040035.trees → trees_newick/r3040035.tree, trees_newick/r3040035_breaks.csv
# ✅ r3040036.trees → trees_newick/r3040036.tree, trees_newick/r3040036_breaks.csv
# ✅ r3040037.trees → trees_newick/r3040037.tree, trees_newick/r3040037_breaks.csv
# ✅ r3040038.trees → trees_newick/r3040038.tree, trees_newick/r3040038_breaks.csv
# ✅ r3040039.trees → trees_newick/r3040039.tree, trees_newick/r3040039_breaks.csv
# ✅ r3040040.trees → trees_newick/r3040040.tree, trees_newick/r3040040_breaks.csv
# ✅ r3040041.trees → trees_newick/r3040041.tree, trees_newick/r3040041_breaks.csv
# ✅ r3040042.trees → trees_newick/r3040042.tree, trees_newick/r3040042_breaks.csv
# ✅ r3040043.trees → trees_newick/r3040043.tree, trees_newick/r3040043_breaks.csv
# ✅ r3040044.trees → trees_newick/r3040044.tree, trees_newick/r3040044_breaks.csv
# ✅ r3040045.trees → trees_newick/r3040045.tree, trees_newick/r3040045_breaks.csv
# ✅ r3040046.trees → trees_newick/r3040046.tree, trees_newick/r3040046_breaks.csv
# ✅ r3040047.trees → trees_newick/r3040047.tree, trees_newick/r3040047_breaks.csv
# ✅ r3040048.trees → trees_newick/r3040048.tree, trees_newick/r3040048_breaks.csv
# ✅ r3040049.trees → trees_newick/r3040049.tree, trees_newick/r3040049_breaks.csv
# ✅ r3040050.trees → trees_newick/r3040050.tree, trees_newick/r3040050_breaks.csv
# ✅ r3040051.trees → trees_newick/r3040051.tree, trees_newick/r3040051_breaks.csv
# ✅ r3040052.trees → trees_newick/r3040052.tree, trees_newick/r3040052_breaks.csv
# ✅ r3040053.trees → trees_newick/r3040053.tree, trees_newick/r3040053_breaks.csv
# ✅ r3040054.trees → trees_newick/r3040054.tree, trees_newick/r3040054_breaks.csv
# ✅ r3040055.trees → trees_newick/r3040055.tree, trees_newick/r3040055_breaks.csv
# ✅ r3040056.trees → trees_newick/r3040056.tree, trees_newick/r3040056_breaks.csv
# ✅ r3040057.trees → trees_newick/r3040057.tree, trees_newick/r3040057_breaks.csv
# ✅ r3040058.trees → trees_newick/r3040058.tree, trees_newick/r3040058_breaks.csv
# ✅ r3040059.trees → trees_newick/r3040059.tree, trees_newick/r3040059_breaks.csv
# ✅ r3040060.trees → trees_newick/r3040060.tree, trees_newick/r3040060_breaks.csv
# ✅ r3040061.trees → trees_newick/r3040061.tree, trees_newick/r3040061_breaks.csv
# ✅ r3040062.trees → trees_newick/r3040062.tree, trees_newick/r3040062_breaks.csv
# ✅ r3040063.trees → trees_newick/r3040063.tree, trees_newick/r3040063_breaks.csv
# ✅ r3040064.trees → trees_newick/r3040064.tree, trees_newick/r3040064_breaks.csv
# ✅ r3040065.trees → trees_newick/r3040065.tree, trees_newick/r3040065_breaks.csv
# ✅ r3040066.trees → trees_newick/r3040066.tree, trees_newick/r3040066_breaks.csv
# ✅ r3040067.trees → trees_newick/r3040067.tree, trees_newick/r3040067_breaks.csv
# ✅ r3040068.trees → trees_newick/r3040068.tree, trees_newick/r3040068_breaks.csv
# ✅ r3040069.trees → trees_newick/r3040069.tree, trees_newick/r3040069_breaks.csv
# ✅ r3040070.trees → trees_newick/r3040070.tree, trees_newick/r3040070_breaks.csv
# ✅ r3040071.trees → trees_newick/r3040071.tree, trees_newick/r3040071_breaks.csv
# ✅ r3040072.trees → trees_newick/r3040072.tree, trees_newick/r3040072_breaks.csv
# ✅ r3040073.trees → trees_newick/r3040073.tree, trees_newick/r3040073_breaks.csv
# ✅ r3040074.trees → trees_newick/r3040074.tree, trees_newick/r3040074_breaks.csv
# ✅ r3040075.trees → trees_newick/r3040075.tree, trees_newick/r3040075_breaks.csv
# ✅ r3040076.trees → trees_newick/r3040076.tree, trees_newick/r3040076_breaks.csv
# ✅ r3040077.trees → trees_newick/r3040077.tree, trees_newick/r3040077_breaks.csv
# ✅ r3040078.trees → trees_newick/r3040078.tree, trees_newick/r3040078_breaks.csv
# ✅ r3040079.trees → trees_newick/r3040079.tree, trees_newick/r3040079_breaks.csv
# ✅ r3040080.trees → trees_newick/r3040080.tree, trees_newick/r3040080_breaks.csv
# ✅ r3040081.trees → trees_newick/r3040081.tree, trees_newick/r3040081_breaks.csv
# ✅ r3040082.trees → trees_newick/r3040082.tree, trees_newick/r3040082_breaks.csv
# ✅ r3040083.trees → trees_newick/r3040083.tree, trees_newick/r3040083_breaks.csv
# ✅ r3040084.trees → trees_newick/r3040084.tree, trees_newick/r3040084_breaks.csv
# ✅ r3040085.trees → trees_newick/r3040085.tree, trees_newick/r3040085_breaks.csv
# ✅ r3040086.trees → trees_newick/r3040086.tree, trees_newick/r3040086_breaks.csv
# ✅ r3040087.trees → trees_newick/r3040087.tree, trees_newick/r3040087_breaks.csv
# ✅ r3040088.trees → trees_newick/r3040088.tree, trees_newick/r3040088_breaks.csv
# ✅ r3040089.trees → trees_newick/r3040089.tree, trees_newick/r3040089_breaks.csv
# ✅ r3040090.trees → trees_newick/r3040090.tree, trees_newick/r3040090_breaks.csv
# ✅ r3040091.trees → trees_newick/r3040091.tree, trees_newick/r3040091_breaks.csv
# ✅ r3040092.trees → trees_newick/r3040092.tree, trees_newick/r3040092_breaks.csv
# ✅ r3040093.trees → trees_newick/r3040093.tree, trees_newick/r3040093_breaks.csv
# ✅ r3040094.trees → trees_newick/r3040094.tree, trees_newick/r3040094_breaks.csv
# ✅ r3040095.trees → trees_newick/r3040095.tree, trees_newick/r3040095_breaks.csv
# ✅ r3040096.trees → trees_newick/r3040096.tree, trees_newick/r3040096_breaks.csv
# ✅ r3040097.trees → trees_newick/r3040097.tree, trees_newick/r3040097_breaks.csv
# ✅ r3040098.trees → trees_newick/r3040098.tree, trees_newick/r3040098_breaks.csv
# ✅ r3040099.trees → trees_newick/r3040099.tree, trees_newick/r3040099_breaks.csv
# ...
# ✅ r3120001.trees → trees_newick/r3120001.tree, trees_newick/r3120001_breaks.csv
# ✅ r3120002.trees → trees_newick/r3120002.tree, trees_newick/r3120002_breaks.csv
# ✅ r3120003.trees → trees_newick/r3120003.tree, trees_newick/r3120003_breaks.csv
# ✅ r3120004.trees → trees_newick/r3120004.tree, trees_newick/r3120004_breaks.csv
# ✅ r3120005.trees → trees_newick/r3120005.tree, trees_newick/r3120005_breaks.csv
# ✅ r3120006.trees → trees_newick/r3120006.tree, trees_newick/r3120006_breaks.csv
# ✅ r3120007.trees → trees_newick/r3120007.tree, trees_newick/r3120007_breaks.csv
# ✅ r3120008.trees → trees_newick/r3120008.tree, trees_newick/r3120008_breaks.csv
# ✅ r3120009.trees → trees_newick/r3120009.tree, trees_newick/r3120009_breaks.csv
# ✅ r3120010.trees → trees_newick/r3120010.tree, trees_newick/r3120010_breaks.csv
# ✅ r3120011.trees → trees_newick/r3120011.tree, trees_newick/r3120011_breaks.csv
# ✅ r3120012.trees → trees_newick/r3120012.tree, trees_newick/r3120012_breaks.csv
# ✅ r3120013.trees → trees_newick/r3120013.tree, trees_newick/r3120013_breaks.csv
# ✅ r3120014.trees → trees_newick/r3120014.tree, trees_newick/r3120014_breaks.csv
# ✅ r3120015.trees → trees_newick/r3120015.tree, trees_newick/r3120015_breaks.csv
# ✅ r3120016.trees → trees_newick/r3120016.tree, trees_newick/r3120016_breaks.csv
# ✅ r3120017.trees → trees_newick/r3120017.tree, trees_newick/r3120017_breaks.csv
# ✅ r3120018.trees → trees_newick/r3120018.tree, trees_newick/r3120018_breaks.csv
# ✅ r3120019.trees → trees_newick/r3120019.tree, trees_newick/r3120019_breaks.csv
# ✅ r3120020.trees → trees_newick/r3120020.tree, trees_newick/r3120020_breaks.csv
# ✅ r3120021.trees → trees_newick/r3120021.tree, trees_newick/r3120021_breaks.csv
# ✅ r3120022.trees → trees_newick/r3120022.tree, trees_newick/r3120022_breaks.csv
# ✅ r3120023.trees → trees_newick/r3120023.tree, trees_newick/r3120023_breaks.csv
# ✅ r3120024.trees → trees_newick/r3120024.tree, trees_newick/r3120024_breaks.csv
# ✅ r3120025.trees → trees_newick/r3120025.tree, trees_newick/r3120025_breaks.csv
# ✅ r3120026.trees → trees_newick/r3120026.tree, trees_newick/r3120026_breaks.csv
# ✅ r3120027.trees → trees_newick/r3120027.tree, trees_newick/r3120027_breaks.csv
# ✅ r3120028.trees → trees_newick/r3120028.tree, trees_newick/r3120028_breaks.csv
# ✅ r3120029.trees → trees_newick/r3120029.tree, trees_newick/r3120029_breaks.csv
# ✅ r3120030.trees → trees_newick/r3120030.tree, trees_newick/r3120030_breaks.csv
# ✅ r3120031.trees → trees_newick/r3120031.tree, trees_newick/r3120031_breaks.csv
# ✅ r3120032.trees → trees_newick/r3120032.tree, trees_newick/r3120032_breaks.csv
# ✅ r3120033.trees → trees_newick/r3120033.tree, trees_newick/r3120033_breaks.csv
# ✅ r3120034.trees → trees_newick/r3120034.tree, trees_newick/r3120034_breaks.csv
# ✅ r3120035.trees → trees_newick/r3120035.tree, trees_newick/r3120035_breaks.csv
# ✅ r3120036.trees → trees_newick/r3120036.tree, trees_newick/r3120036_breaks.csv
# ✅ r3120037.trees → trees_newick/r3120037.tree, trees_newick/r3120037_breaks.csv
# ✅ r3120038.trees → trees_newick/r3120038.tree, trees_newick/r3120038_breaks.csv
# ✅ r3120039.trees → trees_newick/r3120039.tree, trees_newick/r3120039_breaks.csv
# ✅ r3120040.trees → trees_newick/r3120040.tree, trees_newick/r3120040_breaks.csv
# ✅ r3120041.trees → trees_newick/r3120041.tree, trees_newick/r3120041_breaks.csv
# ✅ r3120042.trees → trees_newick/r3120042.tree, trees_newick/r3120042_breaks.csv
# ✅ r3120043.trees → trees_newick/r3120043.tree, trees_newick/r3120043_breaks.csv
# ✅ r3120044.trees → trees_newick/r3120044.tree, trees_newick/r3120044_breaks.csv
# ✅ r3120045.trees → trees_newick/r3120045.tree, trees_newick/r3120045_breaks.csv
# ✅ r3120046.trees → trees_newick/r3120046.tree, trees_newick/r3120046_breaks.csv
# ✅ r3120047.trees → trees_newick/r3120047.tree, trees_newick/r3120047_breaks.csv
# ✅ r3120048.trees → trees_newick/r3120048.tree, trees_newick/r3120048_breaks.csv
# ✅ r3120049.trees → trees_newick/r3120049.tree, trees_newick/r3120049_breaks.csv
# ✅ r3120050.trees → trees_newick/r3120050.tree, trees_newick/r3120050_breaks.csv
# ✅ r3120051.trees → trees_newick/r3120051.tree, trees_newick/r3120051_breaks.csv
# ✅ r3120052.trees → trees_newick/r3120052.tree, trees_newick/r3120052_breaks.csv
# ✅ r3120053.trees → trees_newick/r3120053.tree, trees_newick/r3120053_breaks.csv
# ✅ r3120054.trees → trees_newick/r3120054.tree, trees_newick/r3120054_breaks.csv
# ✅ r3120055.trees → trees_newick/r3120055.tree, trees_newick/r3120055_breaks.csv
# ✅ r3120056.trees → trees_newick/r3120056.tree, trees_newick/r3120056_breaks.csv
# ✅ r3120057.trees → trees_newick/r3120057.tree, trees_newick/r3120057_breaks.csv
# ✅ r3120058.trees → trees_newick/r3120058.tree, trees_newick/r3120058_breaks.csv
# ✅ r3120059.trees → trees_newick/r3120059.tree, trees_newick/r3120059_breaks.csv
# ✅ r3120060.trees → trees_newick/r3120060.tree, trees_newick/r3120060_breaks.csv
# ✅ r3120061.trees → trees_newick/r3120061.tree, trees_newick/r3120061_breaks.csv
# ✅ r3120062.trees → trees_newick/r3120062.tree, trees_newick/r3120062_breaks.csv
# ✅ r3120063.trees → trees_newick/r3120063.tree, trees_newick/r3120063_breaks.csv
# ✅ r3120064.trees → trees_newick/r3120064.tree, trees_newick/r3120064_breaks.csv
# ✅ r3120065.trees → trees_newick/r3120065.tree, trees_newick/r3120065_breaks.csv
# ✅ r3120066.trees → trees_newick/r3120066.tree, trees_newick/r3120066_breaks.csv
# ✅ r3120067.trees → trees_newick/r3120067.tree, trees_newick/r3120067_breaks.csv
# ✅ r3120068.trees → trees_newick/r3120068.tree, trees_newick/r3120068_breaks.csv
# ✅ r3120069.trees → trees_newick/r3120069.tree, trees_newick/r3120069_breaks.csv
# ✅ r3120070.trees → trees_newick/r3120070.tree, trees_newick/r3120070_breaks.csv
# ✅ r3120071.trees → trees_newick/r3120071.tree, trees_newick/r3120071_breaks.csv
# ✅ r3120072.trees → trees_newick/r3120072.tree, trees_newick/r3120072_breaks.csv
# ✅ r3120073.trees → trees_newick/r3120073.tree, trees_newick/r3120073_breaks.csv
# ✅ r3120074.trees → trees_newick/r3120074.tree, trees_newick/r3120074_breaks.csv
# ✅ r3120075.trees → trees_newick/r3120075.tree, trees_newick/r3120075_breaks.csv
# ✅ r3120076.trees → trees_newick/r3120076.tree, trees_newick/r3120076_breaks.csv
# ✅ r3120077.trees → trees_newick/r3120077.tree, trees_newick/r3120077_breaks.csv
# ✅ r3120078.trees → trees_newick/r3120078.tree, trees_newick/r3120078_breaks.csv
# ✅ r3120079.trees → trees_newick/r3120079.tree, trees_newick/r3120079_breaks.csv
# ✅ r3120080.trees → trees_newick/r3120080.tree, trees_newick/r3120080_breaks.csv
# ✅ r3120081.trees → trees_newick/r3120081.tree, trees_newick/r3120081_breaks.csv
# ✅ r3120082.trees → trees_newick/r3120082.tree, trees_newick/r3120082_breaks.csv
# ✅ r3120083.trees → trees_newick/r3120083.tree, trees_newick/r3120083_breaks.csv
# ✅ r3120084.trees → trees_newick/r3120084.tree, trees_newick/r3120084_breaks.csv
# ✅ r3120085.trees → trees_newick/r3120085.tree, trees_newick/r3120085_breaks.csv
# ✅ r3120086.trees → trees_newick/r3120086.tree, trees_newick/r3120086_breaks.csv
# ✅ r3120087.trees → trees_newick/r3120087.tree, trees_newick/r3120087_breaks.csv
# ✅ r3120088.trees → trees_newick/r3120088.tree, trees_newick/r3120088_breaks.csv
# ✅ r3120089.trees → trees_newick/r3120089.tree, trees_newick/r3120089_breaks.csv
# ✅ r3120090.trees → trees_newick/r3120090.tree, trees_newick/r3120090_breaks.csv
# ✅ r3120091.trees → trees_newick/r3120091.tree, trees_newick/r3120091_breaks.csv
# ✅ r3120092.trees → trees_newick/r3120092.tree, trees_newick/r3120092_breaks.csv
# ✅ r3120093.trees → trees_newick/r3120093.tree, trees_newick/r3120093_breaks.csv
# ✅ r3120094.trees → trees_newick/r3120094.tree, trees_newick/r3120094_breaks.csv
# ✅ r3120095.trees → trees_newick/r3120095.tree, trees_newick/r3120095_breaks.csv
# ✅ r3120096.trees → trees_newick/r3120096.tree, trees_newick/r3120096_breaks.csv
# ✅ r3120097.trees → trees_newick/r3120097.tree, trees_newick/r3120097_breaks.csv
# ✅ r3120098.trees → trees_newick/r3120098.tree, trees_newick/r3120098_breaks.csv
# ✅ r3120099.trees → trees_newick/r3120099.tree, trees_newick/r3120099_breaks.csv
# ✅ r4000000.trees → trees_newick/r4000000.tree, trees_newick/r4000000_breaks.csv
# ✅ r4000001.trees → trees_newick/r4000001.tree, trees_newick/r4000001_breaks.csv
# ✅ r4000002.trees → trees_newick/r4000002.tree, trees_newick/r4000002_breaks.csv
# ✅ r4000003.trees → trees_newick/r4000003.tree, trees_newick/r4000003_breaks.csv
# ✅ r4000004.trees → trees_newick/r4000004.tree, trees_newick/r4000004_breaks.csv
# ✅ r4000005.trees → trees_newick/r4000005.tree, trees_newick/r4000005_breaks.csv
# ✅ r4000006.trees → trees_newick/r4000006.tree, trees_newick/r4000006_breaks.csv
# ✅ r4000007.trees → trees_newick/r4000007.tree, trees_newick/r4000007_breaks.csv
# ✅ r4000008.trees → trees_newick/r4000008.tree, trees_newick/r4000008_breaks.csv
# ✅ r4000009.trees → trees_newick/r4000009.tree, trees_newick/r4000009_breaks.csv
# ✅ r4000010.trees → trees_newick/r4000010.tree, trees_newick/r4000010_breaks.csv
# ✅ r4000011.trees → trees_newick/r4000011.tree, trees_newick/r4000011_breaks.csv
# ✅ r4000012.trees → trees_newick/r4000012.tree, trees_newick/r4000012_breaks.csv
# ✅ r4000013.trees → trees_newick/r4000013.tree, trees_newick/r4000013_breaks.csv
# ✅ r4000014.trees → trees_newick/r4000014.tree, trees_newick/r4000014_breaks.csv
# ✅ r4000015.trees → trees_newick/r4000015.tree, trees_newick/r4000015_breaks.csv
# ✅ r4000016.trees → trees_newick/r4000016.tree, trees_newick/r4000016_breaks.csv
# ✅ r4000017.trees → trees_newick/r4000017.tree, trees_newick/r4000017_breaks.csv
# ✅ r4000018.trees → trees_newick/r4000018.tree, trees_newick/r4000018_breaks.csv
# ✅ r4000019.trees → trees_newick/r4000019.tree, trees_newick/r4000019_breaks.csv
# ✅ r4000020.trees → trees_newick/r4000020.tree, trees_newick/r4000020_breaks.csv
# ✅ r4000021.trees → trees_newick/r4000021.tree, trees_newick/r4000021_breaks.csv
# ✅ r4000022.trees → trees_newick/r4000022.tree, trees_newick/r4000022_breaks.csv
# ✅ r4000023.trees → trees_newick/r4000023.tree, trees_newick/r4000023_breaks.csv
# ✅ r4000024.trees → trees_newick/r4000024.tree, trees_newick/r4000024_breaks.csv
# ✅ r4000025.trees → trees_newick/r4000025.tree, trees_newick/r4000025_breaks.csv
# ✅ r4000026.trees → trees_newick/r4000026.tree, trees_newick/r4000026_breaks.csv
# ✅ r4000027.trees → trees_newick/r4000027.tree, trees_newick/r4000027_breaks.csv
# ✅ r4000028.trees → trees_newick/r4000028.tree, trees_newick/r4000028_breaks.csv
# ✅ r4000029.trees → trees_newick/r4000029.tree, trees_newick/r4000029_breaks.csv
# ✅ r4000030.trees → trees_newick/r4000030.tree, trees_newick/r4000030_breaks.csv
# ✅ r4000031.trees → trees_newick/r4000031.tree, trees_newick/r4000031_breaks.csv
# ✅ r4000032.trees → trees_newick/r4000032.tree, trees_newick/r4000032_breaks.csv
# ✅ r4000033.trees → trees_newick/r4000033.tree, trees_newick/r4000033_breaks.csv
# ✅ r4000034.trees → trees_newick/r4000034.tree, trees_newick/r4000034_breaks.csv
# ✅ r4000035.trees → trees_newick/r4000035.tree, trees_newick/r4000035_breaks.csv
# ✅ r4000036.trees → trees_newick/r4000036.tree, trees_newick/r4000036_breaks.csv
# ✅ r4000037.trees → trees_newick/r4000037.tree, trees_newick/r4000037_breaks.csv
# ✅ r4000038.trees → trees_newick/r4000038.tree, trees_newick/r4000038_breaks.csv
# ✅ r4000039.trees → trees_newick/r4000039.tree, trees_newick/r4000039_breaks.csv
# ✅ r4000040.trees → trees_newick/r4000040.tree, trees_newick/r4000040_breaks.csv
# ✅ r4000041.trees → trees_newick/r4000041.tree, trees_newick/r4000041_breaks.csv
# ✅ r4000042.trees → trees_newick/r4000042.tree, trees_newick/r4000042_breaks.csv
# ✅ r4000043.trees → trees_newick/r4000043.tree, trees_newick/r4000043_breaks.csv
# ✅ r4000044.trees → trees_newick/r4000044.tree, trees_newick/r4000044_breaks.csv
# ✅ r4000045.trees → trees_newick/r4000045.tree, trees_newick/r4000045_breaks.csv
# ✅ r4000046.trees → trees_newick/r4000046.tree, trees_newick/r4000046_breaks.csv
# ✅ r4000047.trees → trees_newick/r4000047.tree, trees_newick/r4000047_breaks.csv
# ✅ r4000048.trees → trees_newick/r4000048.tree, trees_newick/r4000048_breaks.csv
# ✅ r4000049.trees → trees_newick/r4000049.tree, trees_newick/r4000049_breaks.csv
# ✅ r4010000.trees → trees_newick/r4010000.tree, trees_newick/r4010000_breaks.csv
# ✅ r4010001.trees → trees_newick/r4010001.tree, trees_newick/r4010001_breaks.csv
# ✅ r4010002.trees → trees_newick/r4010002.tree, trees_newick/r4010002_breaks.csv
# ✅ r4010003.trees → trees_newick/r4010003.tree, trees_newick/r4010003_breaks.csv
# ✅ r4010004.trees → trees_newick/r4010004.tree, trees_newick/r4010004_breaks.csv
# ✅ r4010005.trees → trees_newick/r4010005.tree, trees_newick/r4010005_breaks.csv
# ✅ r4010006.trees → trees_newick/r4010006.tree, trees_newick/r4010006_breaks.csv
# ✅ r4010007.trees → trees_newick/r4010007.tree, trees_newick/r4010007_breaks.csv
# ✅ r4010008.trees → trees_newick/r4010008.tree, trees_newick/r4010008_breaks.csv
# ✅ r4010009.trees → trees_newick/r4010009.tree, trees_newick/r4010009_breaks.csv
# ✅ r4010010.trees → trees_newick/r4010010.tree, trees_newick/r4010010_breaks.csv
# ✅ r4010011.trees → trees_newick/r4010011.tree, trees_newick/r4010011_breaks.csv
# ✅ r4010012.trees → trees_newick/r4010012.tree, trees_newick/r4010012_breaks.csv
# ✅ r4010013.trees → trees_newick/r4010013.tree, trees_newick/r4010013_breaks.csv
# ✅ r4010014.trees → trees_newick/r4010014.tree, trees_newick/r4010014_breaks.csv
# ✅ r4010015.trees → trees_newick/r4010015.tree, trees_newick/r4010015_breaks.csv
# ✅ r4010016.trees → trees_newick/r4010016.tree, trees_newick/r4010016_breaks.csv
# ✅ r4010017.trees → trees_newick/r4010017.tree, trees_newick/r4010017_breaks.csv
# ✅ r4010018.trees → trees_newick/r4010018.tree, trees_newick/r4010018_breaks.csv
# ✅ r4010019.trees → trees_newick/r4010019.tree, trees_newick/r4010019_breaks.csv
# ✅ r4010020.trees → trees_newick/r4010020.tree, trees_newick/r4010020_breaks.csv
# ✅ r4010021.trees → trees_newick/r4010021.tree, trees_newick/r4010021_breaks.csv
# ✅ r4010022.trees → trees_newick/r4010022.tree, trees_newick/r4010022_breaks.csv
# ✅ r4010023.trees → trees_newick/r4010023.tree, trees_newick/r4010023_breaks.csv
# ✅ r4010024.trees → trees_newick/r4010024.tree, trees_newick/r4010024_breaks.csv
# ✅ r4010025.trees → trees_newick/r4010025.tree, trees_newick/r4010025_breaks.csv
# ✅ r4010026.trees → trees_newick/r4010026.tree, trees_newick/r4010026_breaks.csv
# ✅ r4010027.trees → trees_newick/r4010027.tree, trees_newick/r4010027_breaks.csv
# ✅ r4010028.trees → trees_newick/r4010028.tree, trees_newick/r4010028_breaks.csv
# ✅ r4010029.trees → trees_newick/r4010029.tree, trees_newick/r4010029_breaks.csv
# ✅ r4010030.trees → trees_newick/r4010030.tree, trees_newick/r4010030_breaks.csv
# ✅ r4010031.trees → trees_newick/r4010031.tree, trees_newick/r4010031_breaks.csv
# ✅ r4010032.trees → trees_newick/r4010032.tree, trees_newick/r4010032_breaks.csv
# ✅ r4010033.trees → trees_newick/r4010033.tree, trees_newick/r4010033_breaks.csv
# ✅ r4010034.trees → trees_newick/r4010034.tree, trees_newick/r4010034_breaks.csv
# ✅ r4010035.trees → trees_newick/r4010035.tree, trees_newick/r4010035_breaks.csv
# ✅ r4010036.trees → trees_newick/r4010036.tree, trees_newick/r4010036_breaks.csv
# ✅ r4010037.trees → trees_newick/r4010037.tree, trees_newick/r4010037_breaks.csv
# ✅ r4010038.trees → trees_newick/r4010038.tree, trees_newick/r4010038_breaks.csv
# ✅ r4010039.trees → trees_newick/r4010039.tree, trees_newick/r4010039_breaks.csv
# ✅ r4010040.trees → trees_newick/r4010040.tree, trees_newick/r4010040_breaks.csv
# ✅ r4010041.trees → trees_newick/r4010041.tree, trees_newick/r4010041_breaks.csv
# ✅ r4010042.trees → trees_newick/r4010042.tree, trees_newick/r4010042_breaks.csv
# ✅ r4010043.trees → trees_newick/r4010043.tree, trees_newick/r4010043_breaks.csv
# ✅ r4010044.trees → trees_newick/r4010044.tree, trees_newick/r4010044_breaks.csv
# ✅ r4010045.trees → trees_newick/r4010045.tree, trees_newick/r4010045_breaks.csv
# ✅ r4010046.trees → trees_newick/r4010046.tree, trees_newick/r4010046_breaks.csv
# ✅ r4010047.trees → trees_newick/r4010047.tree, trees_newick/r4010047_breaks.csv
# ✅ r4010048.trees → trees_newick/r4010048.tree, trees_newick/r4010048_breaks.csv
# ✅ r4010049.trees → trees_newick/r4010049.tree, trees_newick/r4010049_breaks.csv
# 🎉 All tree files converted successfully with jitter + interval CSVs!
